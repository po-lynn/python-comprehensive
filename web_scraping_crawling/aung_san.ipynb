# %%
import requests
import bs4
res = requests.get('https://en.wikipedia.org/wiki/Aung_San')


# Create a soup from request
soup = bs4.BeautifulSoup(res.text,"lxml")
soup
# note depending on your IP Address, 
# this class may be called something different
soup.select(".mw-headline")
# Out:
# [<span class="mw-headline" id="Early_life_and_education">Early life and education</span>,
#  <span class="mw-headline" id="University_years">University years</span>,
#  <span class="mw-headline" id="Thakin_revolutionary"><i>Thakin</i> revolutionary</span>,
#  <span class="mw-headline" id="World_War_II">World War II</span>,
#  <span class="mw-headline" id="Formation_of_the_Thirty_Comrades">Formation of the Thirty Comrades</span>,
#  <span class="mw-headline" id="Japanese_invasion_and_wartime_administration">Japanese invasion and wartime administration</span>,
#  <span class="mw-headline" id="Post_World_War_II">Post World War II</span>,
#  <span class="mw-headline" id="Aung_San-Attlee_agreement_and_the_Panglong_Conference">Aung San-Attlee agreement and the Panglong Conference</span>,
#  <span class="mw-headline" id="Assassination">Assassination</span>,
#  <span class="mw-headline" id="Ancestry">Ancestry</span>,
#  <span class="mw-headline" id="Legacy">Legacy</span>,
# ...

# %%
for item in soup.select(".mw-headline"):
    print(item.text)
# Out:
# Early life and education
# University years
# Thakin revolutionary
# World War II
# Formation of the Thirty Comrades
# Japanese invasion and wartime administration
# Post World War II
# Aung San-Attlee agreement and the Panglong Conference
# Assassination
# Ancestry
# Legacy
# Family
# Names of Aung San
# See also
# References
# Sources
# External links

# %%
image_info = soup.select('.thumbimage')
image_info
# Out:
# [<img class="thumbimage" data-file-height="656" data-file-width="1012" decoding="async" height="143" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/3d/Oway_magazine_committee.jpg/220px-Oway_magazine_committee.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/3d/Oway_magazine_committee.jpg/330px-Oway_magazine_committee.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/3d/Oway_magazine_committee.jpg/440px-Oway_magazine_committee.jpg 2x" width="220"/>,
# ...

# %%
len(image_info)
union = image_info[0]
union
union['src']
# Out:
# '//upload.wikimedia.org/wikipedia/commons/thumb/3/3d/Oway_magazine_committee.jpg/220px-Oway_magazine_committee.jpg'

# %% [markdown]
# <img src='https://upload.wikimedia.org/wikipedia/commons/thumb/3/3d/Oway_magazine_committee.jpg/220px-Oway_magazine_committee.jpg'>

# %%
image_link = requests.get('https://upload.wikimedia.org/wikipedia/commons/thumb/3/3d/Oway_magazine_committee.jpg/220px-Oway_magazine_committee.jpg')

# %% [markdown]
# **Let's write this to a file:=, not the 'wb' call to denote a binary writing of the file.**

# %%
f = open('my_new_file_name.jpg','wb')
f.write(image_link.content)
f.close()

# %%
image_link.content
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00`\x00`\x00\x00\xff\xfe\x00QFile source: http://commons.wikimedia.org/wiki/File:Oway_magazine_committee.jpg\xff\xdb\x00C\x00\x06\x04\x05\x06\x05\x04\x06\x06\x05\x06\x07\x07\x06\x08\n\x10\n\n\t\t\n\x14\x0e\x0f\x0c\x10\x17\x14\x18\x18\x17\x14\x16\x16\x1a\x1d%\x1f\x1a\x1b#\x1c\x16\x16 , #&\')*)\x19\x1f-0-(0%()(\xff\xc0\x00\x0b\x08\x00\x8f\x00\xdc\x01\x01\x11\x00\xff\xc4\x00\x1c\x00\x00\x01\x05\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x06\x03\x04\x05\x07\x08\x02\x01\x00\xff\xc4\x00?\x10\x00\x02\x01\x03\x03\x02\x04\x05\x03\x01\x07\x02\x04\x07\x00\x00\x01\x02\x03\x04\x05\x11\x00\x12!\x061\x07\x13AQ\x14"aq\x812\x91\xa1\x15\x08#BR\xb1\xc1\xd1\x16\xf0$3b\xe1%Cr\x82\x92\xa2\xf1\xff\xda\x00\x08\x01\x01\x00\x00?\x002\x8e(]\xf0\x15p{\x1ci\xda\xc1\x00\x0cV4\xed\xfe^t\xb4tt\xfc\xbe\xc5\xcf\xbf\xb6\xbb\x8a\x9e\r\xdcF\x06{\x92;\xeb\xdf\x83\x80\x8eU3\xdf\x85\x1a\xe6\xa2:\x1aJy\xaa*\xcct\xf4\xf0\xa1w\x91\xb0\x02\x8fs\xaa\x93\xc4\xce\xa9\xe9\xe
# ...

# %% [markdown]
# <img src='my_new_file_name.jpg'/>
